# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DOGE_USD (2).csv')

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  2021-07-05  0.246419  0.246419  0.227838  0.231614   0.231614  1267949362
# 1  2021-07-06  0.231216  0.241910  0.229842  0.234422   0.234422  1265920169
# 2  2021-07-07  0.234301  0.237851  0.222576  0.224126   0.224126  1148903688
# 3  2021-07-08  0.224383  0.224930  0.202987  0.207597   0.207597  1789637577
# 4  2021-07-09  0.207073  0.229139  0.196607  0.219864   0.219864  3045790264

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       366 non-null    datetime64[ns]
#  1   Open       366 non-null    float64
#  2   High       366 non-null    float64
#  3   Low        366 non-null    float64
#  4   Close      366 non-null    float64
#  5   Adj Close  366 non-null    float64
#  6   Volume     366 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 20.1 KB

# %%
df.drop(100,axis = 0,inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
col = ['Open', 'Low', 'Close', 'Adj Close**', 'Volume']
for x in col:
    df[x] = pd.to_numeric

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#           Date                                         Open      High  \
# 0   2021-07-05  <function to_numeric at 0x00000087324BD4C0>  0.246419
# 1   2021-07-06  <function to_numeric at 0x00000087324BD4C0>  0.241910
# 2   2021-07-07  <function to_numeric at 0x00000087324BD4C0>  0.237851
# 3   2021-07-08  <function to_numeric at 0x00000087324BD4C0>  0.224930
# 4   2021-07-09  <function to_numeric at 0x00000087324BD4C0>  0.229139
# ..         ...                                          ...       ...
# 361 2022-07-01  <function to_numeric at 0x00000087324BD4C0>  0.067862
# 362 2022-07-02  <function to_numeric at 0x00000087324BD4C0>  0.067692
# 363 2022-07-03  <function to_numeric at 0x00000087324BD4C0>  0.067356
# 364 2022-07-04  <function to_numeric at 0x00000087324BD4C0>  0.069605
# 365 2022-07-05  <function to_numeric at 0x00000087324BD4C0>  0.069841
#
#                                              Low  \
# 0    <function to_numeric at 0x00000087324BD4C0>
# ...

# %%
df[(df['Date'] >= pd.Timestamp(2022,4,1)) &(df['Date'] <= pd.Timestamp(2022,5,31))]
# Out:
#           Date                                         Open      High  \
# 270 2022-04-01  <function to_numeric at 0x00000087324BD4C0>  0.142394
# 271 2022-04-02  <function to_numeric at 0x00000087324BD4C0>  0.144069
# 272 2022-04-03  <function to_numeric at 0x00000087324BD4C0>  0.148558
# 273 2022-04-04  <function to_numeric at 0x00000087324BD4C0>  0.155312
# 274 2022-04-05  <function to_numeric at 0x00000087324BD4C0>  0.178045
# ..         ...                                          ...       ...
# 326 2022-05-27  <function to_numeric at 0x00000087324BD4C0>  0.085384
# 327 2022-05-28  <function to_numeric at 0x00000087324BD4C0>  0.083048
# 328 2022-05-29  <function to_numeric at 0x00000087324BD4C0>  0.083034
# 329 2022-05-30  <function to_numeric at 0x00000087324BD4C0>  0.088275
# 330 2022-05-31  <function to_numeric at 0x00000087324BD4C0>  0.088230
#
#                                              Low  \
# 270  <function to_numeric at 0x00000087324BD4C0>
# ...

# %%
df.to_csv('dogedata.csv',index=False)

# %%
df.to_excel('dogedata.xlsx',sheet_name='DOGE', index =False)

# %%
with pd.ExcelWriter('Dogedata101.xlsx',engine='xlsxwriter') as writer:
    df[(df['Date'] >= pd.Timestamp(2022,4,1)) &(df['Date'] <= pd.Timestamp(2022,5,31))].to_excel(writer,sheet_name='APRMAY',index=False,engine='xlsxwriter')
    df[(df['Date'] >= pd.Timestamp(2022,6,1)) &(df['Date'] <= pd.Timestamp(2022,7,5))].to_excel(writer,sheet_name='JUNJUL',index=False,engine='xlsxwriter')
